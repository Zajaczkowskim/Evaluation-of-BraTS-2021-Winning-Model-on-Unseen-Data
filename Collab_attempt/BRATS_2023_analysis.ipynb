# %% [markdown]
# # Analysis of the influence of glioma size on prediction score

# %%
# %pip install synapseclient
# Out:
# Collecting synapseclient
#   Downloading synapseclient-4.8.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: requests<3.0,>=2.22.0 in /usr/local/lib/python3.11/dist-packages (from synapseclient) (2.32.3)
# Collecting urllib3<2,>=1.26.18 (from synapseclient)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 2.1 MB/s eta 0:00:00
# Collecting deprecated<2.0,>=1.2.4 (from synapseclient)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting opentelemetry-api>=1.21.0 (from synapseclient)
#   Downloading opentelemetry_api-1.34.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-sdk>=1.21.0 (from synapseclient)
#   Downloading opentelemetry_sdk-1.34.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-exporter-otlp-proto-http>=1.21.0 (from synapseclient)
#   Downloading opentelemetry_exporter_otlp_proto_http-1.34.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-httpx>=0.48b0 (from synapseclient)
#   Downloading opentelemetry_instrumentation_httpx-0.55b0-py3-none-any.whl.metadata (7.3 kB)
# Collecting opentelemetry-instrumentation-requests>=0.48b0 (from synapseclient)
#   Downloading opentelemetry_instrumentation_requests-0.55b0-py3-none-any.whl.metadata (2.6 kB)
# Collecting opentelemetry-instrumentation-threading>=0.48b0 (from synapseclient)
#   Downloading opentelemetry_instrumentation_threading-0.55b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation-urllib>=0.48b0 (from synapseclient)
#   Downloading opentelemetry_instrumentation_urllib-0.55b0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: nest-asyncio~=1.6.0 in /usr/local/lib/python3.11/dist-packages (from synapseclient) (1.6.0)
# Collecting asyncio-atexit~=1.0.1 (from synapseclient)
#   Downloading asyncio_atexit-1.0.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.11/dist-packages (from synapseclient) (0.28.1)
# Requirement already satisfied: httpcore>=1.0.9 in /usr/local/lib/python3.11/dist-packages (from synapseclient) (1.0.9)
# Requirement already satisfied: tqdm<5.0,>=4.66.2 in /usr/local/lib/python3.11/dist-packages (from synapseclient) (4.67.1)
# Collecting async-lru~=2.0.4 (from synapseclient)
#   Downloading async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Collecting psutil~=5.9.8 (from synapseclient)
#   Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated<2.0,>=1.2.4->synapseclient) (1.17.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpcore>=1.0.9->synapseclient) (2025.4.26)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore>=1.0.9->synapseclient) (0.16.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->synapseclient) (4.9.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->synapseclient) (3.10)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.21.0->synapseclient) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.21.0->synapseclient) (4.14.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.21.0->synapseclient) (1.70.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.34.0 (from opentelemetry-exporter-otlp-proto-http>=1.21.0->synapseclient)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.34.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.34.0 (from opentelemetry-exporter-otlp-proto-http>=1.21.0->synapseclient)
#   Downloading opentelemetry_proto-1.34.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-proto==1.34.0->opentelemetry-exporter-otlp-proto-http>=1.21.0->synapseclient) (5.29.5)
# Collecting opentelemetry-instrumentation==0.55b0 (from opentelemetry-instrumentation-httpx>=0.48b0->synapseclient)
#   Downloading opentelemetry_instrumentation-0.55b0-py3-none-any.whl.metadata (6.7 kB)
# Collecting opentelemetry-semantic-conventions==0.55b0 (from opentelemetry-instrumentation-httpx>=0.48b0->synapseclient)
#   Downloading opentelemetry_semantic_conventions-0.55b0-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-util-http==0.55b0 (from opentelemetry-instrumentation-httpx>=0.48b0->synapseclient)
#   Downloading opentelemetry_util_http-0.55b0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: packaging>=18.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation==0.55b0->opentelemetry-instrumentation-httpx>=0.48b0->synapseclient) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.22.0->synapseclient) (3.4.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.21.0->synapseclient) (3.22.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.27.0->synapseclient) (1.3.1)
# Downloading synapseclient-4.8.0-py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.2/468.2 kB 10.1 MB/s eta 0:00:00
# Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Downloading asyncio_atexit-1.0.1-py3-none-any.whl (3.8 kB)
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading opentelemetry_api-1.34.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 3.8 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_http-1.34.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.34.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.34.0-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 3.7 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_httpx-0.55b0-py3-none-any.whl (15 kB)
# Downloading opentelemetry_instrumentation-0.55b0-py3-none-any.whl (31 kB)
# Downloading opentelemetry_semantic_conventions-0.55b0-py3-none-any.whl (196 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 4.3 MB/s eta 0:00:00
# Downloading opentelemetry_util_http-0.55b0-py3-none-any.whl (7.3 kB)
# Downloading opentelemetry_instrumentation_requests-0.55b0-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation_threading-0.55b0-py3-none-any.whl (9.3 kB)
# Downloading opentelemetry_instrumentation_urllib-0.55b0-py3-none-any.whl (12 kB)
# Downloading opentelemetry_sdk-1.34.0-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.4/118.4 kB 7.7 MB/s eta 0:00:00
# Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 10.2 MB/s eta 0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: urllib3, psutil, opentelemetry-util-http, opentelemetry-proto, deprecated, asyncio-atexit, async-lru, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, opentelemetry-semantic-conventions, opentelemetry-sdk, opentelemetry-instrumentation, opentelemetry-instrumentation-urllib, opentelemetry-instrumentation-threading, opentelemetry-instrumentation-requests, opentelemetry-instrumentation-httpx, opentelemetry-exporter-otlp-proto-http, synapseclient
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.4.0
#     Uninstalling urllib3-2.4.0:
#       Successfully uninstalled urllib3-2.4.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
# Successfully installed async-lru-2.0.5 asyncio-atexit-1.0.1 deprecated-1.2.18 opentelemetry-api-1.34.0 opentelemetry-exporter-otlp-proto-common-1.34.0 opentelemetry-exporter-otlp-proto-http-1.34.0 opentelemetry-instrumentation-0.55b0 opentelemetry-instrumentation-httpx-0.55b0 opentelemetry-instrumentation-requests-0.55b0 opentelemetry-instrumentation-threading-0.55b0 opentelemetry-instrumentation-urllib-0.55b0 opentelemetry-proto-1.34.0 opentelemetry-sdk-1.34.0 opentelemetry-semantic-conventions-0.55b0 opentelemetry-util-http-0.55b0 psutil-5.9.8 synapseclient-4.8.0 urllib3-1.26.20

# %%
# %%shell
#  synapse get -r syn68157018
# Out:
# Synapse username (Optional): Krzysztof_Tkaczyk
# Auth token for user Krzysztof_Tkaczyk:
# Welcome, Krzysztof_Tkaczyk!
#
# [syn68157018:Brats2023_TrainingData]: Syncing Folder from Synapse.
# [syn68198156]: Downloaded to /content/summary_tr.json
# [syn68157019]: Downloaded to /content/OUTPUT_DIRECTORY.zip
# [syn68157020]: Downloaded to /content/labelsTr.zip
# Downloading files: 100% 3.64M/3.64M [00:01<00:00, 2.88MB/s]

# %%
# %%shell
# ls -l
# Out:
# total 3564
# -rw-r--r-- 1 root root 2947242 Jun  7 18:25 labelsTr.zip
# -rw-r--r-- 1 root root  356346 Jun  7 18:25 OUTPUT_DIRECTORY.zip
# drwxr-xr-x 1 root root    4096 Jun  5 13:38 sample_data
# -rw-r--r-- 1 root root  334984 Jun  7 18:25 summary_tr.json
# -rw-r--r-- 1 root root     397 Jun  7 18:25 SYNAPSE_METADATA_MANIFEST.tsv

# %%
import json

# Ścieżka do pliku JSON
sciezka_do_pliku = 'summary_tr.json'

# Wczytanie i wyświetlenie zawartości
with open(sciezka_do_pliku, 'r', encoding='utf-8') as plik:
    dane = json.load(plik)
    print(json.dumps(dane, indent=4, ensure_ascii=False))
# Out:
# {
#     "author": "Fabian",
#     "description": "",
#     "id": "de40ea1b9b48",
#     "name": "",
#     "results": {
#         "all": [
#             {
#                 "1": {
#                     "Accuracy": 0.9974064740143369,
#                     "Dice": 0.04817692276071854,
#                     "False Discovery Rate": 0.9176156333473922,
#                     "False Negative Rate": 0.9659579412106425,
#                     "False Omission Rate": 0.0018639402113265193,
#                     "False Positive Rate": 0.0007324830828615569,
#                     "Jaccard": 0.024683037782738722,
#                     "Negative Predictive Value": 0.9981360597886735,
#                     "Precision": 0.0823843666526079,
#                     "Recall": 0.0340420587893575,
#                     "Total Positives Reference": 17214,
#                     "Total Positives Test": 7113,
#                     "True Negative Rate": 0.9992675169171384
#                 },
#                 "2": {
#                     "Accuracy": 0.9934632616487455,
#                     "Dice": 0.0,
#                     "False Discovery Rate": 1.0,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.006471415627349155,
#                     "False Positive Rate": 6.617643494355452e-05,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9935285843726508,
#                     "Precision": 0.0,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 57773,
#                     "Total Positives Test": 587,
#                     "True Negative Rate": 0.9999338235650564
#                 },
#                 "3": {
#                     "Accuracy": 0.996918682795699,
#                     "Dice": 0.0,
#                     "False Discovery Rate": 1.0,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.002717389477477332,
#                     "False Positive Rate": 0.00036591332099700224,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9972826105225227,
#                     "Precision": 0.0,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 24252,
#                     "Total Positives Test": 3258,
#                     "True Negative Rate": 0.999634086679003
#                 },
#                 "reference": "/content/labelsTr/BRATS_00003.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00003.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 1.0,
#                     "Dice": NaN,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": NaN,
#                     "False Omission Rate": 0.0,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": NaN,
#                     "Negative Predictive Value": 1.0,
#                     "Precision": NaN,
#                     "Recall": NaN,
#                     "Total Positives Reference": 0,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "2": {
#                     "Accuracy": 0.9985411066308244,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.0014588933691756273,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9985411066308244,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 13025,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 0.9997198700716846,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.00028012992831541217,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9997198700716846,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 2501,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_00008.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00008.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.999902329749104,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 9.767025089605735e-05,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.999902329749104,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 872,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "2": {
#                     "Accuracy": 0.9908580869175627,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.009141913082437276,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9908580869175627,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 81619,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 0.9992418234767025,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.000758176523297491,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9992418234767025,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 6769,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_00021.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00021.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9991060707885304,
#                     "Dice": 0.7298879750905337,
#                     "False Discovery Rate": 0.35600812231247014,
#                     "False Negative Rate": 0.15777552136218076,
#                     "False Omission Rate": 0.00022667960610715256,
#                     "False Positive Rate": 0.0006686335702957846,
#                     "Jaccard": 0.574664250692816,
#                     "Negative Predictive Value": 0.9997733203938929,
#                     "Precision": 0.6439918776875299,
#                     "Recall": 0.8422244786378192,
#                     "Total Positives Reference": 12803,
#                     "Total Positives Test": 16744,
#                     "True Negative Rate": 0.9993313664297042
#                 },
#                 "2": {
#                     "Accuracy": 0.9945822132616488,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.005417786738351254,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9945822132616488,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 48370,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 0.996080085125448,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.003919914874551972,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.996080085125448,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 34997,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_00022.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00022.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9966910842293907,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.003308915770609319,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9966910842293907,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 29542,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "2": {
#                     "Accuracy": 0.9901594982078853,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.009840501792114695,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9901594982078853,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 87856,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 0.9955637320788531,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.004436267921146954,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9955637320788531,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 39607,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_00036.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00036.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9999326836917563,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 6.73163082437276e-05,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9999326836917563,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 601,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "2": {
#                     "Accuracy": 0.9987455197132616,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.0012544802867383513,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9987455197132616,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 11200,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 0.9994584453405018,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.0005415546594982079,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9994584453405018,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 4835,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_00044.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00044.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9999135304659498,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 8.646953405017922e-05,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9999135304659498,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 772,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "2": {
#                     "Accuracy": 0.9970677643369176,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.002932235663082437,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9970677643369176,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 26179,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 0.9992337589605734,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.0007662410394265233,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9992337589605734,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 6841,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_00046.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00046.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 1.0,
#                     "Dice": NaN,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": NaN,
#                     "False Omission Rate": 0.0,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": NaN,
#                     "Negative Predictive Value": 1.0,
#                     "Precision": NaN,
#                     "Recall": NaN,
#                     "Total Positives Reference": 0,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "2": {
#                     "Accuracy": 0.9978765681003584,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.0021234318996415772,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9978765681003584,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 18958,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 1.0,
#                     "Dice": NaN,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": NaN,
#                     "False Omission Rate": 0.0,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": NaN,
#                     "Negative Predictive Value": 1.0,
#                     "Precision": NaN,
#                     "Recall": NaN,
#                     "Total Positives Reference": 0,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_00048.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00048.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9949997759856631,
#                     "Dice": 0.28179799864860516,
#                     "False Discovery Rate": 0.8359802232376957,
#                     "False Negative Rate": 0.0004565167769915446,
#                     "False Omission Rate": 4.507243365450447e-07,
#                     "False Positive Rate": 0.005004687620175585,
#                     "Jaccard": 0.1640074906367041,
#                     "Negative Predictive Value": 0.9999995492756635,
#                     "Precision": 0.16401977676230428,
#                     "Recall": 0.9995434832230085,
#                     "Total Positives Reference": 8762,
#                     "Total Positives Test": 53396,
#                     "True Negative Rate": 0.9949953123798244
#                 },
#                 "2": {
#                     "Accuracy": 0.9889764784946237,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.011023521505376345,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9889764784946237,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 98418,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 0.9964560931899642,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.003543906810035842,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9964560931899642,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 31640,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_00053.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00053.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9995011200716846,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.0004988799283154122,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9995011200716846,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 4454,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "2": {
#                     "Accuracy": 0.9937013888888889,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.006298611111111111,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9937013888888889,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 56234,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 0.995099126344086,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.0049008736559139785,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.995099126344086,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 43755,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_00056.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00056.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9995817652329749,
#                     "Dice": 0.002137894174238375,
#                     "False Discovery Rate": 0.0,
#                     "False Negative Rate": 0.9989299090422686,
#                     "False Omission Rate": 0.0004182349544063416,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.001070090957731407,
#                     "Negative Predictive Value": 0.9995817650455937,
#                     "Precision": 1.0,
#                     "Recall": 0.001070090957731407,
#                     "Total Positives Reference": 3738,
#                     "Total Positives Test": 4,
#                     "True Negative Rate": 1.0
#                 },
#                 "2": {
#                     "Accuracy": 0.9987408154121864,
#                     "Dice": 0.0,
#                     "False Discovery Rate": 1.0,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.001137795083743936,
#                     "False Positive Rate": 0.00012166619214981633,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9988622049162561,
#                     "Precision": 0.0,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 10157,
#                     "Total Positives Test": 1085,
#                     "True Negative Rate": 0.9998783338078502
#                 },
#                 "3": {
#                     "Accuracy": 0.9993377016129033,
#                     "Dice": 0.06425067257477449,
#                     "False Discovery Rate": 0.7293333333333334,
#                     "False Negative Rate": 0.9635482133237565,
#                     "False Omission Rate": 0.0006010809599820774,
#                     "False Positive Rate": 6.130616196420302e-05,
#                     "Jaccard": 0.033191628515369526,
#                     "Negative Predictive Value": 0.9993989190400179,
#                     "Precision": 0.27066666666666667,
#                     "Recall": 0.03645178667624349,
#                     "Total Positives Reference": 5569,
#                     "Total Positives Test": 750,
#                     "True Negative Rate": 0.9999386938380358
#                 },
#                 "reference": "/content/labelsTr/BRATS_00061.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00061.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9997904345878136,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.00020956541218637993,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9997904345878136,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 1871,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "2": {
#                     "Accuracy": 0.9965078405017921,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.0034921594982078854,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9965078405017921,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 31178,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 0.999365479390681,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.0006345206093189964,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.999365479390681,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 5665,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_00066.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00066.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9999428763440861,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 5.7123655913978495e-05,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9999428763440861,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 510,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "2": {
#                     "Accuracy": 0.9941685707885305,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.005831429211469534,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9941685707885305,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 52063,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 0.996949708781362,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.003050291218637993,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.996949708781362,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 27233,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_00081.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00081.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.999676523297491,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.00032347670250896057,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.999676523297491,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 2888,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "2": {
#                     "Accuracy": 0.9914719982078853,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.008528001792114695,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9914719982078853,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 76138,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 0.9990460349462366,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.0009539650537634408,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9990460349462366,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 8517,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_00087.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00087.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9951438172043011,
#                     "Dice": 0.45085621643530244,
#                     "False Discovery Rate": 0.03219140837411638,
#                     "False Negative Rate": 0.7061193487665534,
#                     "False Omission Rate": 0.004799761156773417,
#                     "False Positive Rate": 6.676110957870574e-05,
#                     "Jaccard": 0.2910357458220231,
#                     "Negative Predictive Value": 0.9952002388432266,
#                     "Precision": 0.9678085916258836,
#                     "Recall": 0.2938806512334467,
#                     "Total Positives Reference": 60562,
#                     "Total Positives Test": 18390,
#                     "True Negative Rate": 0.9999332388904213
#                 },
#                 "2": {
#                     "Accuracy": 0.9924360439068101,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.007563956093189965,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9924360439068101,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 67531,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 0.9961573700716846,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.003842629928315412,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9961573700716846,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 34307,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_00094.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00094.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9991148073476702,
#                     "Dice": 0.0,
#                     "False Discovery Rate": 1.0,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.0008848569281553298,
#                     "False Positive Rate": 3.363190995697707e-07,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9991151430718447,
#                     "Precision": 0.0,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 7900,
#                     "Total Positives Test": 3,
#                     "True Negative Rate": 0.9999996636809004
#                 },
#                 "2": {
#                     "Accuracy": 0.9777627688172043,
#                     "Dice": 0.0,
#                     "False Discovery Rate": 1.0,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.022207989419038406,
#                     "False Positive Rate": 3.0585127861249006e-05,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9777920105809615,
#                     "Precision": 0.0,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 198267,
#                     "Total Positives Test": 267,
#                     "True Negative Rate": 0.9999694148721388
#                 },
#                 "3": {
#                     "Accuracy": 0.997914538530466,
#                     "Dice": 0.07556725088128692,
#                     "False Discovery Rate": 0.015523932729624823,
#                     "False Negative Rate": 0.9607083849648905,
#                     "False Omission Rate": 0.002084297845232344,
#                     "False Positive Rate": 1.347008160124119e-06,
#                     "Jaccard": 0.03926728586171311,
#                     "Negative Predictive Value": 0.9979157021547677,
#                     "Precision": 0.9844760672703752,
#                     "Recall": 0.03929161503510946,
#                     "Total Positives Reference": 19368,
#                     "Total Positives Test": 773,
#                     "True Negative Rate": 0.9999986529918399
#                 },
#                 "reference": "/content/labelsTr/BRATS_00103.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00103.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9975156810035842,
#                     "Dice": 0.3275119762294585,
#                     "False Discovery Rate": 0.24524874231414195,
#                     "False Negative Rate": 0.7908696662278324,
#                     "False Omission Rate": 0.00228958156873946,
#                     "False Positive Rate": 0.00019714285521721386,
#                     "Jaccard": 0.1958232116311954,
#                     "Negative Predictive Value": 0.9977104184312605,
#                     "Precision": 0.754751257685858,
#                     "Recall": 0.20913033377216758,
#                     "Total Positives Reference": 25826,
#                     "Total Positives Test": 7156,
#                     "True Negative Rate": 0.9998028571447828
#                 },
#                 "2": {
#                     "Accuracy": 0.9888475582437276,
#                     "Dice": 0.0,
#                     "False Discovery Rate": 1.0,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.01059656724701064,
#                     "False Positive Rate": 0.0005678417496589594,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9894034327529894,
#                     "Precision": 0.0,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 94553,
#                     "Total Positives Test": 5016,
#                     "True Negative Rate": 0.999432158250341
#                 },
#                 "3": {
#                     "Accuracy": 0.9984439964157706,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.0015560035842293906,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9984439964157706,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 13892,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_00109.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00109.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9999569892473118,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 4.301075268817204e-05,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9999569892473118,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 384,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "2": {
#                     "Accuracy": 0.9959377240143369,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.004062275985663082,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9959377240143369,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 36268,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 0.9998138440860215,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.00018615591397849464,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9998138440860215,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 1662,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_00113.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00113.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9988138440860215,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.0011861559139784946,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9988138440860215,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 10590,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "2": {
#                     "Accuracy": 0.9935978942652329,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.006402105734767025,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9935978942652329,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 57158,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 0.999178203405018,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.0008217965949820789,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.999178203405018,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 7337,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_00117.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00117.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9940150089605735,
#                     "Dice": 0.018370871146709777,
#                     "False Discovery Rate": 0.9896785913341453,
#                     "False Negative Rate": 0.9165414788849942,
#                     "False Omission Rate": 0.000618386705552991,
#                     "False Positive Rate": 0.005373565527674318,
#                     "Jaccard": 0.009270589980346348,
#                     "Negative Predictive Value": 0.999381613294447,
#                     "Precision": 0.010321408665854716,
#                     "Recall": 0.08345852111500585,
#                     "Total Positives Reference": 5991,
#                     "Total Positives Test": 48443,
#                     "True Negative Rate": 0.9946264344723257
#                 },
#                 "2": {
#                     "Accuracy": 0.9813091397849463,
#                     "Dice": 0.005020451482881572,
#                     "False Discovery Rate": 0.9878502784912412,
#                     "False Negative Rate": 0.9968360851626673,
#                     "False Omission Rate": 0.014914741342097335,
#                     "False Positive Rate": 0.0038920119609725523,
#                     "Jaccard": 0.002516542832037204,
#                     "Negative Predictive Value": 0.9850852586579026,
#                     "Precision": 0.012149721508758766,
#                     "Recall": 0.003163914837332692,
#                     "Total Positives Reference": 133063,
#                     "Total Positives Test": 34651,
#                     "True Negative Rate": 0.9961079880390274
#                 },
#                 "3": {
#                     "Accuracy": 0.9960612679211469,
#                     "Dice": 0.06234167933232008,
#                     "False Discovery Rate": 0.06852589641434259,
#                     "False Negative Rate": 0.967749944824542,
#                     "False Omission Rate": 0.003929651849582351,
#                     "False Positive Rate": 9.671884685924503e-06,
#                     "Jaccard": 0.03217372158309022,
#                     "Negative Predictive Value": 0.9960703481504176,
#                     "Precision": 0.9314741035856574,
#                     "Recall": 0.03225005517545795,
#                     "Total Positives Reference": 36248,
#                     "Total Positives Test": 1255,
#                     "True Negative Rate": 0.9999903281153141
#                 },
#                 "reference": "/content/labelsTr/BRATS_00147.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00147.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9963454301075269,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.0036545698924731183,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9963454301075269,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 32628,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "2": {
#                     "Accuracy": 0.9926097670250896,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.007390232974910395,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9926097670250896,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 65980,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 0.99656541218638,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.0034345878136200717,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.99656541218638,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 30664,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_00176.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_00176.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9997931227598567,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.00020687724014336917,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9997931227598567,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 1847,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "2": {
#                     "Accuracy": 0.9975856854838709,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
# ...
#                     "Negative Predictive Value": 1.0,
#                     "Precision": NaN,
#                     "Recall": NaN,
#                     "Total Positives Reference": 0,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_01483.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_01483.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9900665322580645,
#                     "Dice": 0.5360057759919639,
#                     "False Discovery Rate": 0.0330161966247593,
#                     "False Negative Rate": 0.629239588309376,
#                     "False Omission Rate": 0.009795689612627613,
#                     "False Positive Rate": 0.00019897977641913922,
#                     "Jaccard": 0.36612560842249714,
#                     "Negative Predictive Value": 0.9902043103873723,
#                     "Precision": 0.9669838033752407,
#                     "Recall": 0.37076041169062407,
#                     "Total Positives Reference": 138162,
#                     "Total Positives Test": 52974,
#                     "True Negative Rate": 0.9998010202235809
#                 },
#                 "2": {
#                     "Accuracy": 0.993824708781362,
#                     "Dice": 0.0,
#                     "False Discovery Rate": 1.0,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.006100036248264318,
#                     "False Positive Rate": 7.618152072963458e-05,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9938999637517357,
#                     "Precision": 0.0,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 54457,
#                     "Total Positives Test": 676,
#                     "True Negative Rate": 0.9999238184792704
#                 },
#                 "3": {
#                     "Accuracy": 0.9996010304659498,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.00039896953405017924,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9996010304659498,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 3562,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_01489.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_01489.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9926135752688172,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.007386424731182796,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9926135752688172,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 65946,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "2": {
#                     "Accuracy": 0.9968155241935484,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.003184475806451613,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9968155241935484,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 28431,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 0.9998799283154122,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.00012007168458781363,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9998799283154122,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 1072,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_01505.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_01505.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9907399193548387,
#                     "Dice": 0.021979841953343113,
#                     "False Discovery Rate": 0.0,
#                     "False Negative Rate": 0.9888879585660801,
#                     "False Omission Rate": 0.009261044299972522,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.011112041433919835,
#                     "Negative Predictive Value": 0.9907389557000275,
#                     "Precision": 1.0,
#                     "Recall": 0.011112041433919835,
#                     "Total Positives Reference": 83603,
#                     "Total Positives Test": 929,
#                     "True Negative Rate": 1.0
#                 },
#                 "2": {
#                     "Accuracy": 0.9962599686379928,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.0037400313620071686,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9962599686379928,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 33391,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 1.0,
#                     "Dice": NaN,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": NaN,
#                     "False Omission Rate": 0.0,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": NaN,
#                     "Negative Predictive Value": 1.0,
#                     "Precision": NaN,
#                     "Recall": NaN,
#                     "Total Positives Reference": 0,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_01524.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_01524.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9997791218637992,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.00022087813620071684,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9997791218637992,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 1972,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "2": {
#                     "Accuracy": 0.9969605734767025,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.003039426523297491,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9969605734767025,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 27136,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 0.9990638440860216,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.0009361559139784946,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9990638440860216,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 8358,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_01525.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_01525.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9943670474910394,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.0056329525089605734,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9943670474910394,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 50291,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "2": {
#                     "Accuracy": 0.997983646953405,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.002016353046594982,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.997983646953405,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 18002,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 1.0,
#                     "Dice": NaN,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": NaN,
#                     "False Omission Rate": 0.0,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": NaN,
#                     "Negative Predictive Value": 1.0,
#                     "Precision": NaN,
#                     "Recall": NaN,
#                     "Total Positives Reference": 0,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_01529.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_01529.nii.gz"
#             },
#             {
#                 "1": {
#                     "Accuracy": 0.9973997535842294,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.0026002464157706094,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9973997535842294,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 23215,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "2": {
#                     "Accuracy": 0.9885350582437276,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.011464941756272402,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9885350582437276,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 102359,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "3": {
#                     "Accuracy": 0.9954284274193549,
#                     "Dice": 0.0,
#                     "False Discovery Rate": NaN,
#                     "False Negative Rate": 1.0,
#                     "False Omission Rate": 0.004571572580645162,
#                     "False Positive Rate": 0.0,
#                     "Jaccard": 0.0,
#                     "Negative Predictive Value": 0.9954284274193549,
#                     "Precision": NaN,
#                     "Recall": 0.0,
#                     "Total Positives Reference": 40815,
#                     "Total Positives Test": 0,
#                     "True Negative Rate": 1.0
#                 },
#                 "reference": "/content/labelsTr/BRATS_01658.nii.gz",
#                 "test": "/content/OUTPUT_DIRECTORY_renamed/BRATS_01658.nii.gz"
#             }
#         ],
#         "mean": {
#             "1": {
#                 "Accuracy": 0.9980298252688173,
#                 "Dice": 0.055186405761009395,
#                 "False Discovery Rate": 0.7778315099495404,
#                 "False Negative Rate": 0.9079848154999285,
#                 "False Omission Rate": 0.0011870418971959762,
#                 "False Positive Rate": 0.0007855122804049157,
#                 "Jaccard": 0.03731504818054393,
#                 "Negative Predictive Value": 0.9988129581028041,
#                 "Precision": 0.22216849005045952,
#                 "Recall": 0.09201518450007143,
#                 "Total Positives Reference": 12684.626666666667,
#                 "Total Positives Test": 9097.173333333334,
#                 "True Negative Rate": 0.9992144877195951
#             },
#             "2": {
#                 "Accuracy": 0.9941788612604538,
#                 "Dice": 0.0004360353523110801,
#                 "False Discovery Rate": 0.9868011139661964,
#                 "False Negative Rate": 0.9996403954120084,
#                 "False Omission Rate": 0.005659863161166491,
#                 "False Positive Rate": 0.00016407608898714546,
#                 "Jaccard": 0.00022037561010151732,
#                 "Negative Predictive Value": 0.9943401368388334,
#                 "Precision": 0.013198886033803614,
#                 "Recall": 0.00035960458799165213,
#                 "Total Positives Reference": 50535.98,
#                 "Total Positives Test": 1469.5466666666666,
#                 "True Negative Rate": 0.9998359239110127
#             },
#             "3": {
#                 "Accuracy": 0.9980270833333335,
#                 "Dice": 0.009045151010170843,
#                 "False Discovery Rate": 0.54453751527604,
#                 "False Negative Rate": 0.9933745118132195,
#                 "False Omission Rate": 0.0019474228780630677,
#                 "False Positive Rate": 2.5636860159067667e-05,
#                 "Jaccard": 0.0059165716067520625,
#                 "Negative Predictive Value": 0.998052577121937,
#                 "Precision": 0.45546248472395995,
#                 "Recall": 0.006625488186780497,
#                 "Total Positives Reference": 17573.586666666666,
#                 "Total Positives Test": 416.17333333333335,
#                 "True Negative Rate": 0.9999743631398409
#             }
#         }
#     },
#     "task": "",
#     "timestamp": "2025-06-07 16:49:00.077838"
# }

# %%
import os
import pandas as pd

data = dane
rows = []
for item in data['results']['all']:
    label_filename = os.path.basename(item['reference'])
    prediction_filename = os.path.basename(item['test'])
    for cls in ['1', '2', '3']:
        metrics = item[cls].copy()
        metrics['class'] = int(cls)
        metrics['label_filename'] = label_filename
        metrics['prediction_filename'] = prediction_filename
        rows.append(metrics)

df = pd.DataFrame(rows)
cols = ['label_filename', 'prediction_filename', 'class'] + [col for col in df.columns if col not in ['label_filename', 'prediction_filename', 'class']]
df = df[cols]

print(df)
# Out:
#          label_filename prediction_filename  class  Accuracy      Dice  \
# 0    BRATS_00003.nii.gz  BRATS_00003.nii.gz      1  0.997406  0.048177
# 1    BRATS_00003.nii.gz  BRATS_00003.nii.gz      2  0.993463  0.000000
# 2    BRATS_00003.nii.gz  BRATS_00003.nii.gz      3  0.996919  0.000000
# 3    BRATS_00008.nii.gz  BRATS_00008.nii.gz      1  1.000000       NaN
# 4    BRATS_00008.nii.gz  BRATS_00008.nii.gz      2  0.998541  0.000000
# ..                  ...                 ...    ...       ...       ...
# 445  BRATS_01529.nii.gz  BRATS_01529.nii.gz      2  0.997984  0.000000
# 446  BRATS_01529.nii.gz  BRATS_01529.nii.gz      3  1.000000       NaN
# 447  BRATS_01658.nii.gz  BRATS_01658.nii.gz      1  0.997400  0.000000
# 448  BRATS_01658.nii.gz  BRATS_01658.nii.gz      2  0.988535  0.000000
# 449  BRATS_01658.nii.gz  BRATS_01658.nii.gz      3  0.995428  0.000000
#
#      False Discovery Rate  False Negative Rate  False Omission Rate  \
# 0                0.917616             0.965958             0.001864
# 1                1.000000             1.000000             0.006471
# 2                1.000000             1.000000             0.002717
# 3                     NaN                  NaN             0.000000
# 4                     NaN             1.000000             0.001459
# ..                    ...                  ...                  ...
# 445                   NaN             1.000000             0.002016
# 446                   NaN                  NaN             0.000000
# 447                   NaN             1.000000             0.002600
# 448                   NaN             1.000000             0.011465
# 449                   NaN             1.000000             0.004572
#
#      False Positive Rate   Jaccard  Negative Predictive Value  Precision  \
# 0               0.000732  0.024683                   0.998136   0.082384
# 1               0.000066  0.000000                   0.993529   0.000000
# 2               0.000366  0.000000                   0.997283   0.000000
# 3               0.000000       NaN                   1.000000        NaN
# 4               0.000000  0.000000                   0.998541        NaN
# ..                   ...       ...                        ...        ...
# 445             0.000000  0.000000                   0.997984        NaN
# 446             0.000000       NaN                   1.000000        NaN
# 447             0.000000  0.000000                   0.997400        NaN
# 448             0.000000  0.000000                   0.988535        NaN
# 449             0.000000  0.000000                   0.995428        NaN
#
#        Recall  Total Positives Reference  Total Positives Test  \
# 0    0.034042                      17214                  7113
# 1    0.000000                      57773                   587
# 2    0.000000                      24252                  3258
# 3         NaN                          0                     0
# 4    0.000000                      13025                     0
# ..        ...                        ...                   ...
# 445  0.000000                      18002                     0
# 446       NaN                          0                     0
# 447  0.000000                      23215                     0
# 448  0.000000                     102359                     0
# 449  0.000000                      40815                     0
#
#      True Negative Rate
# 0              0.999268
# 1              0.999934
# 2              0.999634
# 3              1.000000
# 4              1.000000
# ..                  ...
# 445            1.000000
# 446            1.000000
# 447            1.000000
# 448            1.000000
# 449            1.000000
#
# [450 rows x 16 columns]

# %% [markdown]
# ## Total results

# %%
import seaborn as sns
import matplotlib.pyplot as plt

metrics = ['Accuracy', 'Dice', 'Precision', 'Recall',
           'False Discovery Rate', 'False Negative Rate',
           'False Omission Rate', 'False Positive Rate',
           'Jaccard', 'Negative Predictive Value',
           'True Negative Rate']

sns.set(style="whitegrid")

for metric in metrics:
    if metric in df.columns:
        plt.figure(figsize=(8, 5))
        ax = sns.boxplot(
            data=df, x='class', y=metric, palette='Set2', showcaps=True, fliersize=0
        )
        sns.stripplot(
            data=df, x='class', y=metric, color='black', size=4, jitter=True, ax=ax, alpha=0.5
        )

        for cls in sorted(df['class'].unique()):
            vals = df[df['class'] == cls][metric].dropna()
            if not vals.empty:
                min_val = vals.min()
                max_val = vals.max()
                ax.text(cls - 0.66, min_val, f"min: {min_val:.3f}", color='blue', ha='right', va='top', fontsize=8)
                ax.text(cls - 0.66, max_val, f"max: {max_val:.3f}", color='red', ha='right', va='bottom', fontsize=8)

        plt.title(f'Distribution of: {metric}')
        plt.xlabel('Class')
        plt.ylabel(metric)
        plt.tight_layout()
        plt.show()
# Out:
# <ipython-input-5-21767e7c3938>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(
# <ipython-input-5-21767e7c3938>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(
# <ipython-input-5-21767e7c3938>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(
# <ipython-input-5-21767e7c3938>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(
# <ipython-input-5-21767e7c3938>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(
# <ipython-input-5-21767e7c3938>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(
# <ipython-input-5-21767e7c3938>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(
# <ipython-input-5-21767e7c3938>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(
# <ipython-input-5-21767e7c3938>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(
# <ipython-input-5-21767e7c3938>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(
# <ipython-input-5-21767e7c3938>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(

# %% [markdown]
# Same thing but on one plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

metrics = ['Accuracy', 'Dice', 'Precision', 'Recall',
           'False Discovery Rate', 'False Negative Rate',
           'False Omission Rate', 'False Positive Rate',
           'Jaccard', 'Negative Predictive Value',
           'True Negative Rate']

df_long = df.melt(id_vars=['class'], value_vars=metrics, var_name='metric', value_name='value')

g = sns.FacetGrid(df_long, col="metric", col_wrap=1, height=3.5, aspect=1.5, sharey=False)

def plot_box_with_annotations(data, color, **kwargs):
    ax = plt.gca()
    sns.boxplot(data=data, x='class', y='value', palette='Set2', showcaps=True, fliersize=0, ax=ax)
    sns.stripplot(data=data, x='class', y='value', color='black', size=3, jitter=True, alpha=0.5, ax=ax)

    for cls in sorted(data['class'].unique()):
        vals = data[data['class'] == cls]['value'].dropna()
        if not vals.empty:
            min_val = vals.min()
            max_val = vals.max()
            ax.text(cls - 0.66, min_val, f"min: {min_val:.3f}", color='blue', ha='right', va='top', fontsize=7)
            ax.text(cls - 0.66, max_val, f"max: {max_val:.3f}", color='red', ha='right', va='bottom', fontsize=7)

g.map_dataframe(plot_box_with_annotations)

g.set_titles(col_template="{col_name}")
g.set_axis_labels("Class", "Value")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Calculation of sizes of clasess

# %%
# %%shell
# ls -l
# Out:
# total 3564
# -rw-r--r-- 1 root root 2947242 Jun  7 18:25 labelsTr.zip
# -rw-r--r-- 1 root root  356346 Jun  7 18:25 OUTPUT_DIRECTORY.zip
# drwxr-xr-x 1 root root    4096 Jun  5 13:38 sample_data
# -rw-r--r-- 1 root root  334984 Jun  7 18:25 summary_tr.json
# -rw-r--r-- 1 root root     397 Jun  7 18:25 SYNAPSE_METADATA_MANIFEST.tsv

# %%
# %%shell
# unzip /content/OUTPUT_DIRECTORY.zip -d /OUTPUT_DIRECTORY
# Out:
# Archive:  /content/OUTPUT_DIRECTORY.zip
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00838-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00494-001.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01137-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00768-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/plans.pkl
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00645-001.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00109-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01183-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00407-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00311-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01301-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01132-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00840-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00457-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01658-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01370-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01318-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00195-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00523-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00117-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00048-001.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00008-001.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00003-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00331-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00046-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00736-001.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01474-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01052-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00343-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01344-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01090-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01039-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00147-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00493-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01049-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00419-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00203-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00066-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00201-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00510-001.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00044-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01359-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00691-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00480-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01387-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01169-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01184-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00061-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00413-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00036-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00593-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00663-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00340-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00625-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00334-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01421-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01233-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00441-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01322-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01133-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01483-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00780-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01364-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01472-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00056-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00336-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01529-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00280-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00314-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01415-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00735-001.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00260-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00418-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00758-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00081-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01440-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00022-001.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01213-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00589-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00500-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01375-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01304-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01016-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00021-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01469-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01138-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01176-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00176-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01128-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00542-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00641-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00216-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01288-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00730-001.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01489-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01265-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01239-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00087-001.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01524-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00674-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01073-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01095-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00053-001.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00746-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01395-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00732-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00773-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01357-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00525-001.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00378-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00481-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00751-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00723-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00113-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00519-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01525-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00765-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00683-001.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01505-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00733-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00094-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00472-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00816-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00103-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00737-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01334-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01001-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/prediction_time.txt
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01062-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00651-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00192-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01065-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00685-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00444-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01349-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01257-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00469-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00545-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00236-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00601-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00360-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01111-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01254-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01378-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01088-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01339-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01409-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01205-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00742-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-00556-001.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01056-000.nii.gz
#   inflating: /OUTPUT_DIRECTORY/BraTS-GLI-01078-000.nii.gz

# %%
# %%shell
# unzip /content/labelsTr.zip -d /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData
# Out:
# Archive:  /content/labelsTr.zip
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01239.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01505.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01349.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00203.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01001.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01658.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00061.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00773.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00765.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01133.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00737.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00674.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01088.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01525.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01257.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01049.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00641.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00545.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00216.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00723.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00444.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01073.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01288.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01233.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01322.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01524.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01474.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01095.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00053.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00838.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00087.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01440.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01334.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01056.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00542.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00663.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01378.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00469.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00494.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00651.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01090.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00481.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00036.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00201.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00525.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00732.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00593.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00733.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00730.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01472.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01304.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00457.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01375.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00840.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01409.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00419.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00816.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01183.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01016.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00556.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00735.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00176.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00683.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00418.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00046.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00500.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01184.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01213.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00236.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00413.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01395.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00519.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01078.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00523.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01415.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00625.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01052.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01421.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00758.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01339.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00645.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01529.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00311.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00768.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00510.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01265.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00192.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00094.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00280.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01301.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01364.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01128.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00746.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00022.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00441.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00742.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01254.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01176.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01370.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01137.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01318.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00109.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00336.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01065.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01489.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00691.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00066.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01132.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00780.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00260.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01111.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01169.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00589.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00113.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00480.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01469.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00044.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01039.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00360.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00195.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00003.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00117.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00378.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00048.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00472.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01062.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00056.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00685.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01138.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00601.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00340.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01359.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00331.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01205.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00103.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00493.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00081.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00343.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00334.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01483.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01387.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00147.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00021.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00751.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00314.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00407.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01344.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_01357.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00736.nii.gz
#   inflating: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/BRATS_00008.nii.gz

# %%
import os
import shutil
import json

input_dir = "/ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData/"
task_name = "Task02_BrainSSA"
base_output = "/content/nnUNet_raw_data_base/nnUNet_raw_data"
task_dir = os.path.join(base_output, task_name)
labelsTr_dir = os.path.join(task_dir, "labelsTr")

os.makedirs(labelsTr_dir, exist_ok=True)

# Zakładam, że nazwa subdir to nazwa pliku bez rozszerzenia i sufiksów modalności
def get_subdir_name(filename):
    # Usuwamy rozszerzenie .nii.gz i potencjalne modalności / "-seg"
    name = filename.replace(".nii.gz", "")
    for suffix in ["-t1c", "-t1n", "-t2f", "-t2w", "-seg"]:
        if name.endswith(suffix):
            name = name[:-len(suffix)]
    return name

copied_files = []

for file in os.listdir(input_dir):
    if file.endswith(".nii.gz"):
        filepath = os.path.join(input_dir, file)
        subdir = get_subdir_name(file)

        # Tworzymy nazwę docelową, np. BRATS_00008_t1c.nii.gz albo BRATS_00008_seg.nii.gz
        dest_filename = file  # zostawiamy oryginalną nazwę, żeby nie mieszać modalności

        dest_path = os.path.join(labelsTr_dir, dest_filename)
        shutil.copy(filepath, dest_path)
        copied_files.append(dest_filename)

print(f"✅ Skopiowano {len(copied_files)} plików do labelsTr.")

# Tworzenie dataset.json
# Tworzymy listę unikalnych subdirów (bazowych nazw bez modalności i rozszerzeń)
subdirs = sorted(set(get_subdir_name(f) for f in copied_files))

dataset_json = {
    "name": "BraTS2023_SSA_Training",
    "description": "All files copied to labelsTr folder",
    "tensorImageSize": "4D",
    "modality": {
        "0": "T1c",
        "1": "T1n",
        "2": "T2f",
        "3": "T2w"
    },
    "labels": {
        "0": "background",
        "1": "tumor"
    },
    "numTraining": len(subdirs),
    "training": [
        {
            "image": f"./labelsTr/{subdir}-t1c.nii.gz",
            "label": f"./labelsTr/{subdir}-seg.nii.gz"
        } for subdir in subdirs
    ],
    "numTest": 0,
    "test": []
}

with open(os.path.join(task_dir, "dataset.json"), "w") as f:
    json.dump(dataset_json, f, indent=4)

print("✅ dataset.json został utworzony.")
# Out:
# ✅ Skopiowano 150 plików do labelsTr.
# ✅ dataset.json został utworzony.

# %%
# %pip install nibabel
# Out:
# Requirement already satisfied: nibabel in /usr/local/lib/python3.11/dist-packages (5.3.2)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.11/dist-packages (from nibabel) (6.5.2)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from nibabel) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from nibabel) (24.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.11/dist-packages (from nibabel) (4.14.0)

# %%
import nibabel as nib
import numpy as np
import pandas as pd
import os
from tqdm import tqdm

base_path = "/content/nnUNet_raw_data_base/nnUNet_raw_data/Task02_BrainSSA/labelsTr/"
reference_files = df['label_filename'].unique()
reference_paths = [os.path.join(base_path, f) for f in reference_files]

volume_data = []

for path in tqdm(reference_paths, desc="Processing NIfTI files"):
    img = nib.load(path)
    data = img.get_fdata()

    classes, counts = np.unique(data, return_counts=True)
    class_volume = dict(zip(classes.astype(int), counts))

    filename = os.path.basename(path)

    record = {
        'label_filename': filename,
        'volume_class_1': class_volume.get(1, 0),
        'volume_class_2': class_volume.get(2, 0),
        'volume_class_3': class_volume.get(3, 0),
        'volume_total_voxels': int(np.prod(data.shape)),
    }
    volume_data.append(record)

volume_df = pd.DataFrame(volume_data)

df = df.merge(volume_df, on='label_filename', how='left')
# Out:
# Processing NIfTI files: 100%|██████████| 150/150 [00:58<00:00,  2.55it/s]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

metrics = ['Accuracy', 'Dice', 'Precision', 'Recall',
           'False Discovery Rate', 'False Negative Rate',
           'False Omission Rate', 'False Positive Rate',
           'Jaccard', 'Negative Predictive Value',
           'True Negative Rate']

for cls in [1, 2, 3]:
    df[f'volume_frac_{cls}'] = df[f'volume_class_{cls}'] / df['volume_total_voxels']

plot_data = []
for metric in metrics:
    for cls in [1, 2, 3]:
        temp = df[df['class'] == cls].copy()
        temp['metric'] = metric
        temp['value'] = temp[metric]
        temp['volume_frac'] = temp[f'volume_frac_{cls}']
        temp['class'] = str(cls)
        plot_data.append(temp[['metric', 'value', 'volume_frac', 'class']])

plot_df = pd.concat(plot_data)

g = sns.FacetGrid(plot_df, col="metric", col_wrap=4, height=4, aspect=1.3, sharex=False, sharey=False)
g.map_dataframe(sns.scatterplot, x="volume_frac", y="value", hue="class", palette="Set2", alpha=0.8)

g.set_axis_labels("% Volume", "Metric Value")
g.add_legend(title="Class")

for ax, title in zip(g.axes.flat, plot_df['metric'].unique()):
    ax.set_title(title, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
import os
import nibabel as nib
import numpy as np

def list_unique_values_in_folder(folder_path):
    print(f"Folder: {folder_path}")
    for filename in sorted(os.listdir(folder_path)):
        if filename.endswith('.nii.gz'):
            file_path = os.path.join(folder_path, filename)
            img = nib.load(file_path)
            data = img.get_fdata()
            unique_values = np.unique(data)
            unique_values = unique_values[unique_values != 0]  # jeśli chcesz pominąć tło (0)
            print(f"{filename}: unique classes = {unique_values}")

# Podaj ścieżki do folderów
folder1 = '/ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData'
folder2 = '/OUTPUT_DIRECTORY'

list_unique_values_in_folder(folder1)
print("\n---\n")
list_unique_values_in_folder(folder2)
# Out:
# Folder: /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData
# BRATS_00003.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00008.nii.gz: unique classes = [2. 3.]
# BRATS_00021.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00022.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00036.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00044.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00046.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00048.nii.gz: unique classes = [2.]
# BRATS_00053.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00056.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00061.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00066.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00081.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00087.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00094.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00103.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00109.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00113.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00117.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00147.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00176.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00192.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00195.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00201.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00203.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00216.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00236.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00260.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00280.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00311.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00314.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00331.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00334.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00336.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00340.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00343.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00360.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00378.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00407.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00413.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00418.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00419.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00441.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00444.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00457.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00469.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00472.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00480.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00481.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00493.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00494.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00500.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00510.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00519.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00523.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00525.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00542.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00545.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00556.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00589.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00593.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00601.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00625.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00641.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00645.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00651.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00663.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00674.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00683.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00685.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00691.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00723.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00730.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00732.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00733.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00735.nii.gz: unique classes = [2.]
# BRATS_00736.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00737.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00742.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00746.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00751.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00758.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00765.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00768.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00773.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00780.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00816.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00838.nii.gz: unique classes = [1. 2. 3.]
# BRATS_00840.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01001.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01016.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01039.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01049.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01052.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01056.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01062.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01065.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01073.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01078.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01088.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01090.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01095.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01111.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01128.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01132.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01133.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01137.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01138.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01169.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01176.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01183.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01184.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01205.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01213.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01233.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01239.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01254.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01257.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01265.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01288.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01301.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01304.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01318.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01322.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01334.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01339.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01344.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01349.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01357.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01359.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01364.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01370.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01375.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01378.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01387.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01395.nii.gz: unique classes = [2. 3.]
# BRATS_01409.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01415.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01421.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01440.nii.gz: unique classes = [1. 2.]
# BRATS_01469.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01472.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01474.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01483.nii.gz: unique classes = [1. 2.]
# BRATS_01489.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01505.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01524.nii.gz: unique classes = [1. 2.]
# BRATS_01525.nii.gz: unique classes = [1. 2. 3.]
# BRATS_01529.nii.gz: unique classes = [1. 2.]
# BRATS_01658.nii.gz: unique classes = [1. 2. 3.]
#
# ---
#
# Folder: /OUTPUT_DIRECTORY
# BraTS-GLI-00003-000.nii.gz: unique classes = [1. 2. 3.]
# BraTS-GLI-00008-001.nii.gz: unique classes = []
# BraTS-GLI-00021-000.nii.gz: unique classes = []
# BraTS-GLI-00022-001.nii.gz: unique classes = [1.]
# BraTS-GLI-00036-000.nii.gz: unique classes = []
# BraTS-GLI-00044-000.nii.gz: unique classes = []
# BraTS-GLI-00046-000.nii.gz: unique classes = []
# BraTS-GLI-00048-001.nii.gz: unique classes = []
# BraTS-GLI-00053-001.nii.gz: unique classes = [1.]
# BraTS-GLI-00056-000.nii.gz: unique classes = []
# BraTS-GLI-00061-000.nii.gz: unique classes = [1. 2. 3.]
# BraTS-GLI-00066-000.nii.gz: unique classes = []
# BraTS-GLI-00081-000.nii.gz: unique classes = []
# BraTS-GLI-00087-001.nii.gz: unique classes = []
# BraTS-GLI-00094-000.nii.gz: unique classes = [1.]
# BraTS-GLI-00103-000.nii.gz: unique classes = [1. 2. 3.]
# BraTS-GLI-00109-000.nii.gz: unique classes = [1. 2.]
# BraTS-GLI-00113-000.nii.gz: unique classes = []
# BraTS-GLI-00117-000.nii.gz: unique classes = []
# BraTS-GLI-00147-000.nii.gz: unique classes = [1. 2. 3.]
# BraTS-GLI-00176-000.nii.gz: unique classes = []
# BraTS-GLI-00192-000.nii.gz: unique classes = []
# BraTS-GLI-00195-000.nii.gz: unique classes = []
# BraTS-GLI-00201-000.nii.gz: unique classes = []
# BraTS-GLI-00203-000.nii.gz: unique classes = []
# BraTS-GLI-00216-000.nii.gz: unique classes = [1.]
# BraTS-GLI-00236-000.nii.gz: unique classes = []
# BraTS-GLI-00260-000.nii.gz: unique classes = [1. 2. 3.]
# BraTS-GLI-00280-000.nii.gz: unique classes = [1.]
# BraTS-GLI-00311-000.nii.gz: unique classes = []
# BraTS-GLI-00314-000.nii.gz: unique classes = []
# BraTS-GLI-00331-000.nii.gz: unique classes = []
# BraTS-GLI-00334-000.nii.gz: unique classes = []
# BraTS-GLI-00336-000.nii.gz: unique classes = [1. 2. 3.]
# BraTS-GLI-00340-000.nii.gz: unique classes = []
# BraTS-GLI-00343-000.nii.gz: unique classes = []
# BraTS-GLI-00360-000.nii.gz: unique classes = []
# BraTS-GLI-00378-000.nii.gz: unique classes = []
# BraTS-GLI-00407-000.nii.gz: unique classes = []
# BraTS-GLI-00413-000.nii.gz: unique classes = []
# BraTS-GLI-00418-000.nii.gz: unique classes = []
# BraTS-GLI-00419-000.nii.gz: unique classes = []
# BraTS-GLI-00441-000.nii.gz: unique classes = [1. 2.]
# BraTS-GLI-00444-000.nii.gz: unique classes = [1. 2. 3.]
# BraTS-GLI-00457-000.nii.gz: unique classes = [1.]
# BraTS-GLI-00469-000.nii.gz: unique classes = []
# BraTS-GLI-00472-000.nii.gz: unique classes = []
# BraTS-GLI-00480-000.nii.gz: unique classes = []
# BraTS-GLI-00481-000.nii.gz: unique classes = [1. 2. 3.]
# BraTS-GLI-00493-000.nii.gz: unique classes = [1.]
# BraTS-GLI-00494-001.nii.gz: unique classes = [1.]
# BraTS-GLI-00500-000.nii.gz: unique classes = []
# BraTS-GLI-00510-001.nii.gz: unique classes = [1.]
# BraTS-GLI-00519-000.nii.gz: unique classes = []
# BraTS-GLI-00523-000.nii.gz: unique classes = []
# BraTS-GLI-00525-001.nii.gz: unique classes = [1.]
# BraTS-GLI-00542-000.nii.gz: unique classes = []
# BraTS-GLI-00545-000.nii.gz: unique classes = []
# BraTS-GLI-00556-001.nii.gz: unique classes = [1. 2. 3.]
# BraTS-GLI-00589-000.nii.gz: unique classes = [1. 2.]
# BraTS-GLI-00593-000.nii.gz: unique classes = [1.]
# BraTS-GLI-00601-000.nii.gz: unique classes = [1.]
# BraTS-GLI-00625-000.nii.gz: unique classes = []
# BraTS-GLI-00641-000.nii.gz: unique classes = [1.]
# BraTS-GLI-00645-001.nii.gz: unique classes = []
# BraTS-GLI-00651-000.nii.gz: unique classes = []
# BraTS-GLI-00663-000.nii.gz: unique classes = []
# BraTS-GLI-00674-000.nii.gz: unique classes = []
# BraTS-GLI-00683-001.nii.gz: unique classes = [1.]
# BraTS-GLI-00685-000.nii.gz: unique classes = [1.]
# BraTS-GLI-00691-000.nii.gz: unique classes = []
# BraTS-GLI-00723-000.nii.gz: unique classes = []
# BraTS-GLI-00730-001.nii.gz: unique classes = [1. 2.]
# BraTS-GLI-00732-000.nii.gz: unique classes = []
# BraTS-GLI-00733-000.nii.gz: unique classes = []
# BraTS-GLI-00735-001.nii.gz: unique classes = []
# BraTS-GLI-00736-001.nii.gz: unique classes = [1.]
# BraTS-GLI-00737-000.nii.gz: unique classes = []
# BraTS-GLI-00742-000.nii.gz: unique classes = [1.]
# BraTS-GLI-00746-000.nii.gz: unique classes = []
# BraTS-GLI-00751-000.nii.gz: unique classes = []
# BraTS-GLI-00758-000.nii.gz: unique classes = [1.]
# BraTS-GLI-00765-000.nii.gz: unique classes = []
# BraTS-GLI-00768-000.nii.gz: unique classes = [1.]
# BraTS-GLI-00773-000.nii.gz: unique classes = []
# BraTS-GLI-00780-000.nii.gz: unique classes = [1. 2.]
# BraTS-GLI-00816-000.nii.gz: unique classes = [1. 2.]
# BraTS-GLI-00838-000.nii.gz: unique classes = []
# BraTS-GLI-00840-000.nii.gz: unique classes = []
# BraTS-GLI-01001-000.nii.gz: unique classes = [1.]
# BraTS-GLI-01016-000.nii.gz: unique classes = []
# BraTS-GLI-01039-000.nii.gz: unique classes = []
# BraTS-GLI-01049-000.nii.gz: unique classes = []
# BraTS-GLI-01052-000.nii.gz: unique classes = []
# BraTS-GLI-01056-000.nii.gz: unique classes = []
# BraTS-GLI-01062-000.nii.gz: unique classes = []
# BraTS-GLI-01065-000.nii.gz: unique classes = []
# BraTS-GLI-01073-000.nii.gz: unique classes = []
# BraTS-GLI-01078-000.nii.gz: unique classes = [1.]
# BraTS-GLI-01088-000.nii.gz: unique classes = []
# BraTS-GLI-01090-000.nii.gz: unique classes = []
# BraTS-GLI-01095-000.nii.gz: unique classes = []
# BraTS-GLI-01111-000.nii.gz: unique classes = [1. 2. 3.]
# BraTS-GLI-01128-000.nii.gz: unique classes = []
# BraTS-GLI-01132-000.nii.gz: unique classes = []
# BraTS-GLI-01133-000.nii.gz: unique classes = []
# BraTS-GLI-01137-000.nii.gz: unique classes = []
# BraTS-GLI-01138-000.nii.gz: unique classes = []
# BraTS-GLI-01169-000.nii.gz: unique classes = []
# BraTS-GLI-01176-000.nii.gz: unique classes = []
# BraTS-GLI-01183-000.nii.gz: unique classes = [1. 2. 3.]
# BraTS-GLI-01184-000.nii.gz: unique classes = [1. 2.]
# BraTS-GLI-01205-000.nii.gz: unique classes = []
# BraTS-GLI-01213-000.nii.gz: unique classes = []
# BraTS-GLI-01233-000.nii.gz: unique classes = []
# BraTS-GLI-01239-000.nii.gz: unique classes = []
# BraTS-GLI-01254-000.nii.gz: unique classes = []
# BraTS-GLI-01257-000.nii.gz: unique classes = []
# BraTS-GLI-01265-000.nii.gz: unique classes = [1.]
# BraTS-GLI-01288-000.nii.gz: unique classes = []
# BraTS-GLI-01301-000.nii.gz: unique classes = [1.]
# BraTS-GLI-01304-000.nii.gz: unique classes = [1.]
# BraTS-GLI-01318-000.nii.gz: unique classes = [1.]
# BraTS-GLI-01322-000.nii.gz: unique classes = []
# BraTS-GLI-01334-000.nii.gz: unique classes = []
# BraTS-GLI-01339-000.nii.gz: unique classes = []
# BraTS-GLI-01344-000.nii.gz: unique classes = []
# BraTS-GLI-01349-000.nii.gz: unique classes = []
# BraTS-GLI-01357-000.nii.gz: unique classes = []
# BraTS-GLI-01359-000.nii.gz: unique classes = [1.]
# BraTS-GLI-01364-000.nii.gz: unique classes = []
# BraTS-GLI-01370-000.nii.gz: unique classes = []
# BraTS-GLI-01375-000.nii.gz: unique classes = []
# BraTS-GLI-01378-000.nii.gz: unique classes = [1.]
# BraTS-GLI-01387-000.nii.gz: unique classes = []
# BraTS-GLI-01395-000.nii.gz: unique classes = []
# BraTS-GLI-01409-000.nii.gz: unique classes = []
# BraTS-GLI-01415-000.nii.gz: unique classes = [1.]
# BraTS-GLI-01421-000.nii.gz: unique classes = [1. 2.]
# BraTS-GLI-01440-000.nii.gz: unique classes = [1. 2.]
# BraTS-GLI-01469-000.nii.gz: unique classes = []
# BraTS-GLI-01472-000.nii.gz: unique classes = []
# BraTS-GLI-01474-000.nii.gz: unique classes = [1. 2. 3.]
# BraTS-GLI-01483-000.nii.gz: unique classes = []
# BraTS-GLI-01489-000.nii.gz: unique classes = [1. 2.]
# BraTS-GLI-01505-000.nii.gz: unique classes = []
# BraTS-GLI-01524-000.nii.gz: unique classes = [1.]
# BraTS-GLI-01525-000.nii.gz: unique classes = []
# BraTS-GLI-01529-000.nii.gz: unique classes = []
# BraTS-GLI-01658-000.nii.gz: unique classes = []

# %%
import os
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from tqdm import tqdm

def plot_average_class_distribution(folder_path):
    class_counts_sum = defaultdict(int)
    file_list = [f for f in sorted(os.listdir(folder_path)) if f.endswith('.nii.gz')]
    file_count = len(file_list)

    if file_count == 0:
        print(f"No NIfTI files found in {folder_path}")
        return

    for filename in tqdm(file_list, desc=f"Processing files in {folder_path}"):
        file_path = os.path.join(folder_path, filename)
        img = nib.load(file_path)
        data = img.get_fdata()
        values, counts = np.unique(data, return_counts=True)

        mask = values != 0
        values = values[mask]
        counts = counts[mask]

        for v, c in zip(values, counts):
            class_counts_sum[v] += c

    avg_counts = {cls: count / file_count for cls, count in class_counts_sum.items()}

    classes = sorted(avg_counts.keys())
    avg_values = [avg_counts[cls] for cls in classes]

    plt.figure(figsize=(8, 5))
    plt.bar(classes, avg_values, color='coral')
    plt.xlabel('Classes (voxel values)')
    plt.ylabel('Average number of voxels per file')
    plt.title(f'Average class distribution in folder:\n{folder_path}')
    plt.xticks(classes)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

folder1 = '/ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData'
folder2 = '/OUTPUT_DIRECTORY'

plot_average_class_distribution(folder1)
plot_average_class_distribution(folder2)
# Out:
# Processing files in /ASNR-MICCAI-BraTS2023-SSA-Challenge-TrainingData: 100%|██████████| 150/150 [00:55<00:00,  2.72it/s]
# Processing files in /OUTPUT_DIRECTORY: 100%|██████████| 150/150 [00:30<00:00,  4.98it/s]

# %%
 # !synapse get -r syn59059776
# Out:
# Synapse username (Optional): Krzysztof_Tkaczyk
# Auth token for user Krzysztof_Tkaczyk:
# Welcome, Krzysztof_Tkaczyk!
#
# [syn59059776:BraTS-GLI]: Syncing Folder from Synapse.
# [syn59808905]: Downloaded to /content/CITATIONS.bib
# [syn64735496]: Downloaded to /content/BraTS-PTG supplementary demographic information and metadata.xlsx
# [syn60086071]: Downloaded to /content/BraTS2024-BraTS-GLI-TrainingData.zip
# [syn61455507]: Downloaded to /content/BraTS2024-BraTS-GLI-ValidationData.zip
# [syn64314352]: Downloaded to /content/BraTS2024-BraTS-GLI-AdditionalTrainingData.zip
# Downloading files: 100% 48.1G/48.1G [16:29<00:00, 48.6MB/s]

# %%
import pandas as pd
data = pd.read_excel("/content/BraTS-PTG supplementary demographic information and metadata.xlsx")

# %%
data.columns
# Out:
# Index(['BraTS Subject ID', 'Site', 'Site Subject ID', 'Annotator 1',
#        'Approver 1', 'Train/Test/Validation ', 'Magnetic Field Strength',
#        'Manufacturer', 'Patient's Age', 'Patient's Sex', 'Glioma type '],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1809 entries, 0 to 1808
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   BraTS Subject ID         1809 non-null   object
#  1   Site                     1809 non-null   object
#  2   Site Subject ID          781 non-null    object
#  3   Annotator 1              1110 non-null   object
#  4   Approver 1               1809 non-null   object
#  5   Train/Test/Validation    1809 non-null   object
#  6   Magnetic Field Strength  1809 non-null   float64
#  7   Manufacturer             1796 non-null   object
#  8   Patient's Age            1790 non-null   float64
#  9   Patient's Sex            1809 non-null   object
#  10  Glioma type              1809 non-null   object
# dtypes: float64(2), object(9)
# memory usage: 155.6+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is called 'data'
# Optional: check unique glioma types
print(data['Glioma type '].unique())
data['Glioma type'] = data['Glioma type '].str.strip().str.lower().str.title()
print(data['Glioma type'].unique())

# Create histogram
plt.figure(figsize=(10, 6))
sns.histplot(data=data, x="Patient's Age", hue='Glioma type', bins=15, multiple='stack', palette='Set2')

plt.title('Patient Age Distribution by Glioma Type')
plt.xlabel('Patient Age')
plt.ylabel('Number of Patients')
plt.legend(title='Glioma Type', loc='upper right')
plt.tight_layout()
plt.show()
# Out:
# ['Oligodendroglioma' 'Glioblastoma' 'Glioma NOS' 'Astrocytoma' 'Other'
#  'glioma NOS']
# ['Oligodendroglioma' 'Glioblastoma' 'Glioma Nos' 'Astrocytoma' 'Other']
# <ipython-input-18-6e5c1a6a3293>:18: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Glioma Type', loc='upper right')
